# %% [markdown]
# # Exercise_4_07122020

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
'data': range(6)}, columns=['key', 'data'])
print(df)
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
df.groupby("key").sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %%
rng = np.random.RandomState(0)
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', "C"], \
                   "data1": range(6), "data2": rng.randint(0, 10, 6)},columns = ["key", "data1", "data2"])
print(df1)
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df1.groupby("key").sum()
# Out:
#      data1  data2
# key
# A        3      8
# B        5      7
# C        7     12

# %%
df1.groupby("key").aggregate({"data1":np.median,"data2":max})
# Out:
#      data1  data2
# key
# A      1.5      5
# B      2.5      7
# C      3.5      9

# %% [markdown]
# ## Example

# %%
data=pd.read_csv("F:/TrainingData_latest.csv",sep=";")

# %%
data.shape
# Out:
# (13949, 22)

# %%
# ?pd.read_csv

# %%
data1=pd.read_csv("F:/TrainingData_latest.csv",sep=",",nrows=5)

# %%
data1.shape
# Out:
# (5, 1)

# %%
data.head()
# Out:
#    ID   NumComplains          hour_id      LCID  \
# 0   1              1  11/20/2015 0:03  33378111
# 1   2              1  11/20/2015 0:27  23596112
# 2   3              1  11/20/2015 0:29  10611113
# 3   4              1  11/20/2015 2:11  50982112
# 4   5              1  11/20/2015 2:12  24738113
#
#     RACH_Setup_Completion_Success_Rate_AVG  \
# 0                                 0.992407
# 1                                 0.999230
# 2                                 0.984591
# 3                                 0.994961
# 4                                 0.985488
#
#     Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 0                                       0.998720
# 1                                       0.993518
# 2                                       0.998783
# 3                                       0.998095
# 4                                       0.998673
#
#     Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# ...

# %%
data.tail()
# Out:
#           ID   NumComplains           hour_id      LCID  \
# 13944  13945              0  11/26/2015 23:00  24933231
# 13945  13946              0  11/26/2015 23:00  324U1111
# 13946  13947              0  11/26/2015 23:00  36723112
# 13947  13948              0  11/26/2015 23:00  80315233
# 13948  13949              0  11/26/2015 23:00  84701233
#
#         RACH_Setup_Completion_Success_Rate_AVG  \
# 13944                                 0.998932
# 13945                                 0.995830
# 13946                                 1.000000
# 13947                                 0.998753
# 13948                                 1.000000
#
#         Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 13944                                       0.996762
# 13945                                       0.999482
# 13946                                       0.999697
# 13947                                       0.998970
# 13948                                       0.995388
#
# ...

# %%
data.isnull().head()
# Out:
#       ID   NumComplains   hour_id   LCID  \
# 0  False          False     False  False
# 1  False          False     False  False
# 2  False          False     False  False
# 3  False          False     False  False
# 4  False          False     False  False
#
#     RACH_Setup_Completion_Success_Rate_AVG  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#     Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#     Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# 0                                              False
# ...

# %%
data.isnull().sum()
# Out:
# ID                                                            0
#  NumComplains                                                 0
#  hour_id                                                      0
#  LCID                                                         0
#  RACH_Setup_Completion_Success_Rate_AVG                       1
#  Total_RRC_Connection_Setup_Success_Ratio_AVG                 2
#  Total_RRC_Connection_Re_establishment_Success_Ratio_AVG    411
#  Radio_Bearer_Success_Ratio_AVG                               2
#  ERAB_SetupSR_AVG                                             2
#  HO_Success_Ratio_intra_eNB_AVG                             150
#  Average_CQI_AVG                                              1
#  Radio_Bearer_Drop_Ratio_AVG                                380
#  Average_Physical_Resource_Block_Usage_UL_AVG                80
#  Average_Physical_Resource_Block_Usage_DL_AVG                 0
#  Complete_RACH_Setup_Success_Rate_AVG                         2
# ...

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
#  Total_RRC_Connection_Re_establishment_Success_Ratio_AVG    411
#  Radio_Bearer_Drop_Ratio_AVG                                380
#  HO_Success_Ratio_intra_eNB_AVG                             150
#  Average_Physical_Resource_Block_Usage_UL_AVG                80
#  ERAB_SetupSR_AVG                                             2
#  Total_RRC_Connection_Setup_Success_Ratio_AVG                 2
#  Complete_RACH_Setup_Success_Rate_AVG                         2
#  Radio_Bearer_Success_Ratio_AVG                               2
#  Average_CQI_AVG                                              1
#  RACH_Setup_Completion_Success_Rate_AVG                       1
#  NumComplains                                                 0
#  hour_id                                                      0
#  LCID                                                         0
#  ERAB_Drop_Ratio_with_UE_Lost_cause_initiated_by_eNB_AVG      0
#  AGG_level_block_Rate_AVG                                     0
# ...

# %%
data.isnull().sum().sort_values(ascending=False).iloc[:5]
# Out:
#  Total_RRC_Connection_Re_establishment_Success_Ratio_AVG    411
#  Radio_Bearer_Drop_Ratio_AVG                                380
#  HO_Success_Ratio_intra_eNB_AVG                             150
#  Average_Physical_Resource_Block_Usage_UL_AVG                80
#  ERAB_SetupSR_AVG                                             2
# dtype: int64

# %%
L_columns_null=list(data.isnull().sum().sort_values(ascending=False).iloc[:5].index)

# %%
L_columns_null
# Out:
# [' Total_RRC_Connection_Re_establishment_Success_Ratio_AVG',
#  ' Radio_Bearer_Drop_Ratio_AVG',
#  ' HO_Success_Ratio_intra_eNB_AVG',
#  ' Average_Physical_Resource_Block_Usage_UL_AVG',
#  ' ERAB_SetupSR_AVG']
